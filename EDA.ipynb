# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"C:\Users\user\Downloads\vgsales.csv")

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.shape
# Out:
# (16598, 11)

# %%
df.size
# Out:
# 182578

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.tail()
# Out:
#         Rank                                              Name Platform  \
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year     Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16593  2002.0  Platform       Kemco      0.01      0.00       0.0
# 16594  2003.0   Shooter  Infogrames      0.01      0.00       0.0
# 16595  2008.0    Racing  Activision      0.00      0.00       0.0
# 16596  2010.0    Puzzle    7G//AMES      0.00      0.01       0.0
# 16597  2003.0  Platform     Wanadoo      0.01      0.00       0.0
#
#        Other_Sales  Global_Sales
# 16593          0.0          0.01
# 16594          0.0          0.01
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df.nunique()
# Out:
# Rank            16598
# Name            11493
# Platform           31
# Year               39
# Genre              12
# Publisher         578
# NA_Sales          409
# EU_Sales          305
# JP_Sales          244
# Other_Sales       157
# Global_Sales      623
# dtype: int64

# %%
df["Year"].mean()
# Out:
# np.float64(2006.4064433147546)

# %%
df.dropna(subset=["Year"],inplace=True)

# %%
df.shape
# Out:
# (16327, 11)

# %%
df.isnull().sum()
# Out:
# Rank             0
# Name             0
# Platform         0
# Year             0
# Genre            0
# Publisher       36
# NA_Sales         0
# EU_Sales         0
# JP_Sales         0
# Other_Sales      0
# Global_Sales     0
# dtype: int64

# %%
df["Publisher"].fillna("unknown",inplace=True)

# %%
df.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %% [markdown]
# # publisher

# %%
df["Publisher"].unique()
# Out:
# array(['Nintendo', 'Microsoft Game Studios', 'Take-Two Interactive',
#        'Sony Computer Entertainment', 'Activision', 'Ubisoft',
#        'Bethesda Softworks', 'Electronic Arts', 'Sega', 'SquareSoft',
#        'Atari', '505 Games', 'Capcom', 'GT Interactive',
#        'Konami Digital Entertainment',
#        'Sony Computer Entertainment Europe', 'Square Enix', 'LucasArts',
#        'Virgin Interactive', 'Warner Bros. Interactive Entertainment',
#        'Universal Interactive', 'Eidos Interactive', 'RedOctane',
#        'Vivendi Games', 'Enix Corporation', 'Namco Bandai Games',
#        'Palcom', 'Hasbro Interactive', 'THQ', 'Fox Interactive',
#        'Acclaim Entertainment', 'MTV Games', 'Disney Interactive Studios',
#        'Majesco Entertainment', 'Codemasters', 'Red Orb', 'Level 5',
#        'Arena Entertainment', 'Midway Games', 'JVC', 'Deep Silver',
#        '989 Studios', 'NCSoft', 'UEP Systems', 'Parker Bros.', 'Maxis',
# ...

# %%
df["Publisher"].nunique()
# Out:
# 577

# %%
df["Publisher"].value_counts()
# Out:
# Publisher
# Electronic Arts                 1339
# Activision                       966
# Namco Bandai Games               928
# Ubisoft                          918
# Konami Digital Entertainment     823
#                                 ...
# Navarre Corp                       1
# MediaQuest                         1
# Max Five                           1
# Monte Christo Multimedia           1
# UIG Entertainment                  1
# Name: count, Length: 577, dtype: int64

# %%
df["Publisher"].value_counts().head(10)
# Out:
# Publisher
# Electronic Arts                 1339
# Activision                       966
# Namco Bandai Games               928
# Ubisoft                          918
# Konami Digital Entertainment     823
# THQ                              712
# Nintendo                         696
# Sony Computer Entertainment      682
# Sega                             632
# Take-Two Interactive             412
# Name: count, dtype: int64

# %%
df["Publisher"].value_counts().head(10).plot(kind="bar",title="top 10 publishers",color="green");

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df.groupby("Publisher")["Genre"].get_group("Electronic Arts").value_counts()
# Out:
# Genre
# Sports          554
# Action          182
# Racing          159
# Shooter         139
# Simulation      116
# Misc             43
# Fighting         38
# Strategy         37
# Role-Playing     35
# Platform         16
# Adventure        13
# Puzzle            7
# Name: count, dtype: int64

# %%
df.groupby("Publisher")["Genre"].get_group("Electronic Arts").value_counts().plot(kind="bar",title="genre of electonic arts");

# %%
df[(df["Publisher"]=="Electronic Arts")&(df["Genre"]=="Sports")]
# Out:
#         Rank                             Name Platform    Year   Genre  \
# 77        78                          FIFA 16      PS4  2015.0  Sports
# 112      113                          FIFA 14      PS3  2013.0  Sports
# 121      122                          FIFA 12      PS3  2011.0  Sports
# 124      125                          FIFA 15      PS4  2014.0  Sports
# 199      200                   FIFA Soccer 11      PS3  2010.0  Sports
# ...      ...                              ...      ...     ...     ...
# 15802  15805                 Football Academy       DS  2009.0  Sports
# 15837  15840                   FIFA Soccer 08       PC  2007.0  Sports
# 16012  16015  UEFA Champions League 2006-2007      PSP  2007.0  Sports
# 16127  16130                    Madden NFL 13      PS3  2012.0  Sports
# 16162  16165        Tiger Woods PGA Tour 2005       PC  2004.0  Sports
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
eas=df[(df["Publisher"]=="Electronic Arts")&(df["Genre"]=="Sports")]

# %%
eas
# Out:
#         Rank                             Name Platform    Year   Genre  \
# 77        78                          FIFA 16      PS4  2015.0  Sports
# 112      113                          FIFA 14      PS3  2013.0  Sports
# 121      122                          FIFA 12      PS3  2011.0  Sports
# 124      125                          FIFA 15      PS4  2014.0  Sports
# 199      200                   FIFA Soccer 11      PS3  2010.0  Sports
# ...      ...                              ...      ...     ...     ...
# 15802  15805                 Football Academy       DS  2009.0  Sports
# 15837  15840                   FIFA Soccer 08       PC  2007.0  Sports
# 16012  16015  UEFA Champions League 2006-2007      PSP  2007.0  Sports
# 16127  16130                    Madden NFL 13      PS3  2012.0  Sports
# 16162  16165        Tiger Woods PGA Tour 2005       PC  2004.0  Sports
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
eas[eas["Global_Sales"]==eas["Global_Sales"].max()]
# Out:
#     Rank     Name Platform    Year   Genre        Publisher  NA_Sales  \
# 77    78  FIFA 16      PS4  2015.0  Sports  Electronic Arts      1.11
#
#     EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 77      6.06      0.06         1.26          8.49

# %%
eas["Global_Sales"].max()
# Out:
# 8.49

# %%
eas[eas["Global_Sales"]==eas["Global_Sales"].max()][["Name","Year","Global_Sales"]]
# Out:
#        Name    Year  Global_Sales
# 77  FIFA 16  2015.0          8.49

# %%
eas[eas["Global_Sales"]==eas["Global_Sales"].max()][["NA_Sales","EU_Sales","JP_Sales","Other_Sales"]]
# Out:
#     NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 77      1.11      6.06      0.06         1.26

# %%
eas[eas["Global_Sales"]==eas["Global_Sales"].max()][["NA_Sales","EU_Sales","JP_Sales","Other_Sales"]].plot(kind="bar",title="fifa 16 sales distributio")
# Out:
# <Axes: title={'center': 'fifa 16 sales distributio'}>

# %%
df.groupby("Publisher")["Global_Sales"].sum().sort_values(ascending=False).head(10).plot(kind="bar",title="top tp performning publiher")
# Out:
# <Axes: title={'center': 'top tp performning publiher'}, xlabel='Publisher'>

# %%
df.groupby('Publisher')["Genre"].get_group("Nintendo").value_counts().plot(kind="bar",title="genre of nindent")
# Out:
# <Axes: title={'center': 'genre of nindent'}, xlabel='Genre'>

# %%
df[(df["Publisher"]=="Nintendo")&(df["Genre"]=="Platform")]
# Out:
#         Rank                                             Name Platform  \
# 1          2                                Super Mario Bros.      NES
# 6          7                            New Super Mario Bros.       DS
# 8          9                        New Super Mario Bros. Wii      Wii
# 18        19                                Super Mario World     SNES
# 21        22                                 Super Mario Land       GB
# ...      ...                                              ...      ...
# 8404    8406                              Densetsu no Stafi 4       DS
# 10747  10749                              Famicom Mini: Mappy      GBA
# 11282  11284                        Famicom Mini: Mario Bros.      GBA
# 11759  11761  Famicom Mini: Hikari Shinwa: Palutena no Kagami      GBA
# 15991  15994                          Donkey Kong Jungle Beat      Wii
#
#          Year     Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
nind=df[(df["Publisher"]=="Nintendo")&(df["Genre"]=="Platform")]

# %%
nind
# Out:
#         Rank                                             Name Platform  \
# 1          2                                Super Mario Bros.      NES
# 6          7                            New Super Mario Bros.       DS
# 8          9                        New Super Mario Bros. Wii      Wii
# 18        19                                Super Mario World     SNES
# 21        22                                 Super Mario Land       GB
# ...      ...                                              ...      ...
# 8404    8406                              Densetsu no Stafi 4       DS
# 10747  10749                              Famicom Mini: Mappy      GBA
# 11282  11284                        Famicom Mini: Mario Bros.      GBA
# 11759  11761  Famicom Mini: Hikari Shinwa: Palutena no Kagami      GBA
# 15991  15994                          Donkey Kong Jungle Beat      Wii
#
#          Year     Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
nind[nind["Global_Sales"]==nind["Global_Sales"].max()][["Name","NA_Sales","EU_Sales","JP_Sales","Other_Sales"]]
# Out:
#                 Name  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 1  Super Mario Bros.     29.08      3.58      6.81         0.77

# %%
nind[nind["Global_Sales"]==nind["Global_Sales"].max()][["Name","NA_Sales","EU_Sales","JP_Sales","Other_Sales"]].plot(kind="bar",title="super mario bros")
# Out:
# <Axes: title={'center': 'super mario bros'}>

# %%
df.groupby("Publisher")["Genre"].get_group("Activision").value_counts().plot(kind="bar",title="genre of ACTIVISION");

# %%
df[(df["Publisher"]=="Activision")&(df["Genre"]=="Action")]
# Out:
#         Rank                                         Name Platform    Year  \
# 241      242                        Spider-Man: The Movie      PS2  2002.0
# 324      325  LEGO Indiana Jones: The Original Adventures     X360  2008.0
# 390      391                                 Spider-Man 2      PS2  2004.0
# 411      412                    True Crime: Streets of LA      PS2  2003.0
# 441      442                                   Spider-Man       PS  2000.0
# ...      ...                                          ...      ...     ...
# 16221  16224                    Spider-Man: Friend or Foe       PC  2007.0
# 16406  16409              The Amazing Spider-Man 2 (2014)       PC  2014.0
# 16411  16414           Teenage Mutant Ninja Turtles (3DS)      3DS  2013.0
# 16444  16447                  Madagascar: Escape 2 Africa       PC  2008.0
# 16537  16540              Transformers: Fall of Cybertron       PC  2012.0
#
# ...

# %%
act=df[(df["Publisher"]=="Activision")&(df["Genre"]=="Action")]

# %%
act
# Out:
#         Rank                                         Name Platform    Year  \
# 241      242                        Spider-Man: The Movie      PS2  2002.0
# 324      325  LEGO Indiana Jones: The Original Adventures     X360  2008.0
# 390      391                                 Spider-Man 2      PS2  2004.0
# 411      412                    True Crime: Streets of LA      PS2  2003.0
# 441      442                                   Spider-Man       PS  2000.0
# ...      ...                                          ...      ...     ...
# 16221  16224                    Spider-Man: Friend or Foe       PC  2007.0
# 16406  16409              The Amazing Spider-Man 2 (2014)       PC  2014.0
# 16411  16414           Teenage Mutant Ninja Turtles (3DS)      3DS  2013.0
# 16444  16447                  Madagascar: Escape 2 Africa       PC  2008.0
# 16537  16540              Transformers: Fall of Cybertron       PC  2012.0
#
# ...

# %%
act[act["Global_Sales"]==act["Global_Sales"].max()]
# Out:
#      Rank                   Name Platform    Year   Genre   Publisher  \
# 241   242  Spider-Man: The Movie      PS2  2002.0  Action  Activision
#
#      NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 241      2.71      1.51      0.03         0.23          4.48

# %%
act[act["Global_Sales"]==act["Global_Sales"].max()][["Name","NA_Sales","EU_Sales","JP_Sales","Other_Sales"]]
# Out:
#                       Name  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 241  Spider-Man: The Movie      2.71      1.51      0.03         0.23

# %%
act[act["Global_Sales"]==act["Global_Sales"].max()][["NA_Sales","EU_Sales","JP_Sales","Other_Sales"]].plot(kind="bar",title="spider man")
# Out:
# <Axes: title={'center': 'spider man'}>
