# %%
import pandas as pd

# %% [markdown]
# # 1

# %%
df=pd.read_csv(r"C:\Users\user\Downloads\archive\netflix_titles.csv")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # 2

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %% [markdown]
# # 3

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# # 4

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# # 5

# %%
df.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %% [markdown]
# # 6

# %%
df.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %% [markdown]
# # 7

# %%
df[df["type"]=="Movie"]
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %% [markdown]
# # 8

# %%
df[df["country"]=="India"]
# Out:
#      show_id     type                          title                 director  \
# 4         s5  TV Show                   Kota Factory                      NaN
# 24       s25    Movie                          Jeans               S. Shankar
# 39       s40  TV Show                   Chhota Bheem                      NaN
# 50       s51  TV Show                  Dharmakshetra                      NaN
# 66       s67  TV Show  Raja Rasoi Aur Anya Kahaniyan                      NaN
# ...      ...      ...                            ...                      ...
# 8773   s8774    Movie            Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  TV Show                Yeh Meri Family                      NaN
# 8798   s8799    Movie                       Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                          Zenda           Avadhoot Gupte
# 8806   s8807    Movie                         Zubaan              Mozez Singh
#
# ...

# %% [markdown]
# # 9

# %%
df[df["release_year"]>2015]
# Out:
#      show_id     type                      title         director  \
# 0         s1    Movie       Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show              Blood & Water              NaN
# 2         s3  TV Show                  Ganglands  Julien Leclercq
# 3         s4  TV Show      Jailbirds New Orleans              NaN
# 4         s5  TV Show               Kota Factory              NaN
# ...      ...      ...                        ...              ...
# 8787   s8788    Movie  You Can’t Fight Christmas      Kenny Young
# 8794   s8795    Movie                     اشتباك     Mohamed Diab
# 8796   s8797  TV Show                 Yunus Emre              NaN
# 8797   s8798  TV Show                  Zak Storm              NaN
# 8803   s8804  TV Show                Zombie Dumb              NaN
#
#                                                    cast  \
# 0                                                   NaN
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %% [markdown]
# # 10

# %%
df[df["title"].str.contains("Love")]
# Out:
#      show_id     type                           title  \
# 25       s26  TV Show            Love on the Spectrum
# 158     s159    Movie         Love Don't Cost a Thing
# 159     s160    Movie                  Love in a Puff
# 206     s207    Movie       LSD: Love, Sex Aur Dhokha
# 227     s228    Movie                     Really Love
# ...      ...      ...                             ...
# 8567   s8568  TV Show  The Year of Happiness and Love
# 8575   s8576  TV Show                 This Is My Love
# 8649   s8650    Movie           Two Lovers and a Bear
# 8721   s8722  TV Show                   What Is Love?
# 8725   s8726    Movie            What's Up With Love?
#
#                        director  \
# 25                          NaN
# 158                   Troy Byer
# 159              Pang Ho-cheung
# 206            Dibakar Banerjee
# 227       Angel Kristi Williams
# ...                         ...
# 8567                        NaN
# 8575                        NaN
# ...

# %% [markdown]
# # 11

# %%
df[df["duration"]>"90min"]
# Out:
#      show_id   type                             title  \
# 6         s7  Movie  My Little Pony: A New Generation
# 13       s14  Movie  Confessions of an Invisible Girl
# 18       s19  Movie                         Intrusion
# 28       s29  Movie                        Dark Skies
# 38       s39  Movie               Birth of the Dragon
# ...      ...    ...                               ...
# 8774   s8775  Movie                         يوم الدين
# 8781   s8782  Movie           Yo-Kai Watch: The Movie
# 8791   s8792  Movie                       Young Adult
# 8794   s8795  Movie                            اشتباك
# 8801   s8802  Movie                           Zinzana
#
#                            director  \
# 6     Robert Cullen, José Luis Ucha
# 13                    Bruno Garotti
# 18                       Adam Salky
# 28                    Scott Stewart
# 38                     George Nolfi
# ...                             ...
# 8774                Abu Bakr Shawky
# ...

# %% [markdown]
# # 12

# %%
df.dropna(subset="director")
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...                             ...
# ...

# %% [markdown]
# #  13

# %%
df["country"].fillna("unknown")
# Out:
# 0       United States
# 1        South Africa
# 2             unknown
# 3             unknown
# 4               India
#             ...
# 8802    United States
# 8803          unknown
# 8804    United States
# 8805    United States
# 8806            India
# Name: country, Length: 8807, dtype: object

# %% [markdown]
# # 14

# %%
df["cast"].isnull().sum()
# Out:
# np.int64(825)

# %% [markdown]
# # 15

# %%
df["rating"].fillna("not rated")
# Out:
# 0       PG-13
# 1       TV-MA
# 2       TV-MA
# 3       TV-MA
# 4       TV-MA
#         ...
# 8802        R
# 8803    TV-Y7
# 8804        R
# 8805       PG
# 8806    TV-14
# Name: rating, Length: 8807, dtype: object

# %% [markdown]
# # 16

# %%
df["date_added"]=pd.to_datetime(df["date_added"],format="mixed")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # 17

# %%
df["year_added"]=df["date_added"].dt.year

# %%
df["year_added"]
# Out:
# 0       2021.0
# 1       2021.0
# 2       2021.0
# 3       2021.0
# 4       2021.0
#          ...
# 8802    2019.0
# 8803    2019.0
# 8804    2019.0
# 8805    2020.0
# 8806    2019.0
# Name: year_added, Length: 8807, dtype: float64

# %% [markdown]
# # 18

# %%
df["month_added"]=df["date_added"].dt.month_name()

# %%
df["month_added"]
# Out:
# 0       September
# 1       September
# 2       September
# 3       September
# 4       September
#           ...
# 8802     November
# 8803         July
# 8804     November
# 8805      January
# 8806        March
# Name: month_added, Length: 8807, dtype: object

# %% [markdown]
# # 19

# %%
df[df["year_added"]==2020].shape[0]
# Out:
# 1879

# %% [markdown]
# # 20

# %%
df["month_added"].value_counts().head(1)
# Out:
# month_added
# July    827
# Name: count, dtype: int64

# %% [markdown]
# # 21

# %%
df.groupby("release_year").size()
# Out:
# release_year
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       4
#         ...
# 2017    1032
# 2018    1147
# 2019    1030
# 2020     953
# 2021     592
# Length: 74, dtype: int64

# %% [markdown]
# # 22

# %%
df.groupby("type").size()
# Out:
# type
# Movie      6131
# TV Show    2676
# dtype: int64

# %% [markdown]
# # 23

# %% [markdown]
# # 24

# %%
df["country"].value_counts().head(3)
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Name: count, dtype: int64

# %% [markdown]
# # 25

# %%
df[df["type"]=="TV Show"].groupby("release_year").size()
# Out:
# release_year
# 1925      1
# 1945      1
# 1946      1
# 1963      1
# 1967      1
# 1972      1
# 1974      1
# 1977      1
# 1979      1
# 1981      1
# 1985      1
# 1986      2
# 1988      2
# 1989      1
# 1990      3
# 1991      1
# 1992      3
# 1993      4
# 1994      2
# 1995      2
# 1996      3
# 1997      4
# 1998      4
# 1999      7
# 2000      4
# 2001      5
# 2002      7
# 2003     10
# 2004      9
# 2005     13
# 2006     14
# 2007     14
# 2008     23
# 2009     34
# 2010     40
# 2011     40
# 2012     64
# 2013     63
# 2014     88
# 2015    162
# 2016    244
# 2017    265
# 2018    380
# 2019    397
# 2020    436
# 2021    315
# dtype: int64

# %% [markdown]
# # 26

# %%
df[df["director"].str.contains("Martin",na=False)]["title"]
# Out:
# 143                                         Green Lantern
# 149                                     I Got the Hook Up
# 579                                          Midnight Run
# 903                                               Nayattu
# 944                                       S.M.A.R.T Chase
# 1089                                Two Distant Strangers
# 1358                                       Shutter Island
# 1642                                            The Beast
# 1736                             Operation Christmas Drop
# 2632                         No Direction Home: Bob Dylan
# 2860                                                 Hugo
# 3227                                         The Irishman
# 3646                      Demetri Martin: The Overthinker
# 3759    Rolling Thunder Revue: A Bob Dylan Story by Ma...
# 4993                                         The Outsider
# 5068                    Countdown to Death: Pablo Escobar
# ...

# %% [markdown]
# # 27

# %%
df["first_actor"]=df["cast"].str.split(",").str[0]

# %%
df["first_actor"]
# Out:
# 0                   NaN
# 1            Ama Qamata
# 2         Sami Bouajila
# 3                   NaN
# 4            Mayur More
#              ...
# 8802       Mark Ruffalo
# 8803                NaN
# 8804    Jesse Eisenberg
# 8805          Tim Allen
# 8806      Vicky Kaushal
# Name: first_actor, Length: 8807, dtype: object

# %% [markdown]
# # 28

# %%
df["listed_in"].str.contains("Comedy",na=False).sum()
# Out:
# np.int64(399)

# %% [markdown]
# # 29

# %%
df["title_length"]=df["title"].str.len()

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df["title_length"]
# Out:
# 0       20
# 1       13
# 2        9
# 3       21
# 4       12
#         ..
# 8802     6
# 8803    11
# 8804    10
# 8805     4
# 8806     6
# Name: title_length, Length: 8807, dtype: int64

# %% [markdown]
# # 30

# %%
df["listed_in"]=df["listed_in"].str.lower()

# %%
df["listed_in"]
# Out:
# 0                                           documentaries
# 1         international tv shows, tv dramas, tv mysteries
# 2       crime tv shows, international tv shows, tv act...
# 3                                  docuseries, reality tv
# 4       international tv shows, romantic tv shows, tv ...
#                               ...
# 8802                       cult movies, dramas, thrillers
# 8803               kids' tv, korean tv shows, tv comedies
# 8804                              comedies, horror movies
# 8805                   children & family movies, comedies
# 8806       dramas, international movies, music & musicals
# Name: listed_in, Length: 8807, dtype: object

# %% [markdown]
# # 31

# %%
df.sort_values(by="release_year",ascending=False)
# Out:
#      show_id     type                                          title  \
# 693     s694    Movie                         Ali & Ratu Ratu Queens
# 781     s782    Movie          Black Holes | The Edge of All We Know
# 762     s763    Movie                                   Sweet & Sour
# 763     s764  TV Show                                    Sweet Tooth
# 764     s765    Movie                   Trippin' with the Kandasamys
# ...      ...      ...                                            ...
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8763   s8764    Movie                WWII: Report from the Aleutians
# 8205   s8206    Movie                           The Battle of Midway
# 7790   s7791    Movie                                 Prelude to War
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
#
#             director                                               cast  \
# ...

# %% [markdown]
# # 32

# %% [markdown]
# ###  oldest

# %%
df[df["release_year"]==df["release_year"].min()]
# Out:
#      show_id     type                              title director cast  \
# 4250   s4251  TV Show  Pioneers: First Women Filmmakers*      NaN  NaN
#
#      country date_added  release_year rating  duration listed_in  \
# 4250     NaN 2018-12-30          1925  TV-14  1 Season  tv shows
#
#                                             description  year_added  \
# 4250  This collection restores films from women who ...      2018.0
#
#      month_added first_actor  title_length
# 4250    December         NaN            33

# %%
df[df["release_year"]==df["release_year"].max()]
# Out:
#      show_id     type                      title         director  \
# 1         s2  TV Show              Blood & Water              NaN
# 2         s3  TV Show                  Ganglands  Julien Leclercq
# 3         s4  TV Show      Jailbirds New Orleans              NaN
# 4         s5  TV Show               Kota Factory              NaN
# 5         s6  TV Show              Midnight Mass    Mike Flanagan
# ...      ...      ...                        ...              ...
# 1468   s1469    Movie  What Happened to Mr. Cha?     Kim Dong-kyu
# 1551   s1552  TV Show                      Hilda              NaN
# 1696   s1697  TV Show               Polly Pocket              NaN
# 2920   s2921  TV Show              Love Is Blind              NaN
# 8437   s8438  TV Show     The Netflix Afterparty              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %% [markdown]
# # 33

# %%
df.sort_values(by="title").head(5)
# Out:
#      show_id   type                          title  \
# 2036   s2037  Movie                         #Alive
# 2304   s2305  Movie  #AnneFrank - Parallel Stories
# 2481   s2482  Movie              #FriendButMarried
# 2324   s2325  Movie            #FriendButMarried 2
# 5973   s5974  Movie                          #Roxy
#
#                          director  \
# 2036                       Cho Il
# 2304  Sabina Fedeli, Anna Migotto
# 2481                Rako Prijanto
# 2324                Rako Prijanto
# 5973              Michael Kennedy
#
#                                                    cast      country  \
# 2036                           Yoo Ah-in, Park Shin-hye  South Korea
# 2304                        Helen Mirren, Gengher Gatti        Italy
# 2481  Adipati Dolken, Vanesha Prescilla, Rendi Jhon,...    Indonesia
# 2324  Adipati Dolken, Mawar de Jongh, Sari Nila, Von...    Indonesia
# 5973  Jake Short, Sarah Fisher, Booboo Stewart, Dann...       Canada
#
# ...

# %% [markdown]
# # 34

# %%
df.set_index("show_id",inplace=True)

# %% [markdown]
# # 35

# %%
df.columns
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'year_added', 'month_added', 'first_actor', 'title_length'],
#       dtype='object')

# %%
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#         date_added  release_year rating   duration  \
# show_id
# s1      2021-09-25          2020  PG-13     90 min
# ...

# %% [markdown]
# # 35

# %%
df.reset_index("show_id",inplace=True)

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %% [markdown]
# # 36

# %%
df["content_age"]=2024-df["release_year"]

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # 37

# %%
df["is_movie"]=df["type"]=="Movie"

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # 38

# %%
df["duration_int"]=df["duration"].str.split().str[0]

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # 42

# %%
df[(df["director"]=="Christopher Nolan")&(df["country"]=="United States, United Kingdom")]
# Out:
#     show_id   type      title           director  \
# 340    s341  Movie  Inception  Christopher Nolan
#
#                                                   cast  \
# 340  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
#
#                            country date_added  release_year rating duration  \
# 340  United States, United Kingdom 2021-08-01          2010  PG-13  148 min
#
#                                            listed_in  \
# 340  action & adventure, sci-fi & fantasy, thrillers
#
#                                            description  year_added  \
# 340  A troubled thief who extracts secrets from peo...      2021.0
#
#     month_added        first_actor  title_length  content_age  is_movie  \
# 340      August  Leonardo DiCaprio             9           14      True
#
#     duration_int
# 340          148

# %% [markdown]
# # 43

# %%
df[(df["listed_in"].str.contains("Thriller|Drama",na=False))&(df["release_year"]==2021)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, year_added, month_added, first_actor, title_length, content_age, is_movie, duration_int]
# Index: []

# %% [markdown]
# # 44

# %%
df["title"].str.contains("Tom Hanks").sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 45

# %%
df["listed_in"].str.split(",").value_counts().max()
# Out:
# 362

# %% [markdown]
# # 46

# %%
df.groupby(["rating","type"]).size()
# Out:
# rating    type
# 66 min    Movie         1
# 74 min    Movie         1
# 84 min    Movie         1
# G         Movie        41
# NC-17     Movie         3
# NR        Movie        75
#           TV Show       5
# PG        Movie       287
# PG-13     Movie       490
# R         Movie       797
#           TV Show       2
# TV-14     Movie      1427
#           TV Show     733
# TV-G      Movie       126
#           TV Show      94
# TV-MA     Movie      2062
#           TV Show    1145
# TV-PG     Movie       540
#           TV Show     323
# TV-Y      Movie       131
#           TV Show     176
# TV-Y7     Movie       139
#           TV Show     195
# TV-Y7-FV  Movie         5
#           TV Show       1
# UR        Movie         3
# dtype: int64

# %% [markdown]
# # 49

# %%
df["director"].value_counts().head()
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Name: count, dtype: int64
